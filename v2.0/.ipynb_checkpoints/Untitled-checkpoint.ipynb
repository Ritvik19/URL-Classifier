# %% [markdown]
# # Libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Data

# %%
clean_url = pd.read_csv('../DataSet/CleanURL.csv')

# %%
clean_url.head()
# Out:
#              URL
# 0     google.com
# 1    youtube.com
# 2   facebook.com
# 3      baidu.com
# 4  wikipedia.org

# %%
clean_url['URL'] = clean_url['URL'].apply(lambda x: x if x.startswith('https://') or x.startswith('http://') else 'https://'+x)

# %%
malicious_url = pd.read_csv('../DataSet/MaliciousURL.csv')

# %%
malicious_url.head()
# Out:
#                                                  URL
# 0                   http://atualizacaodedados.online
# 1                     http://webmasteradmin.ukit.me/
# 2           http://stcdxmt.bigperl.in/klxtv/apps/uk/
# 3   https://tubuh-syarikat.com/plugins/fields/files/
# 4  http://rolyborgesmd.com/exceword/excel.php?.ra...

# %%
clean_url['Label'] = 0

# %%
malicious_url['Label'] = 1

# %%
f= open('../DataSet/URL.txt', 'r')

# %%
cont = f.read()

# %%
url = []
for c in cont.split('\n'):
    url.append(c.split(','))

# %%
url
# Out:
# [['http://google.com', '0'],
#  ['http://facebook.com', '0'],
#  ['http://youtube.com', '0'],
#  ['http://yahoo.com', '0'],
#  ['http://baidu.com', '0'],
#  ['http://wikipedia.org', '0'],
#  ['http://qq.com', '0'],
#  ['http://linkedin.com', '0'],
#  ['http://live.com', '0'],
#  ['http://twitter.com', '0'],
#  ['http://amazon.com', '0'],
#  ['http://taobao.com', '0'],
#  ['http://blogspot.com', '0'],
#  ['http://google.co.in', '0'],
#  ['http://wordpress.com', '0'],
#  ['http://sina.com.cn', '0'],
#  ['http://yandex.ru', '0'],
#  ['http://yahoo.co.jp', '0'],
#  ['http://bing.com', '0'],
#  ['http://hao123.com', '0'],
#  ['http://google.de', '0'],
#  ['http://vk.com', '0'],
#  ['http://ebay.com', '0'],
#  ['http://163.com', '0'],
#  ['http://googleusercontent.com', '0'],
#  ['http://google.co.uk', '0'],
#  ['http://tumblr.com', '0'],
#  ['http://pinterest.com', '0'],
#  ['http://google.fr', '0'],
#  ['http://apple.com', '0'],
#  ['http://msn.com', '0'],
#  ['http://google.com.br', '0'],
#  ['http://weibo.com', '0'],
#  ['http://mail.ru', '0'],
#  ['http://microsoft.com', '0'],
#  ['http://google.co.jp', '0'],
#  ['http://soso.com', '0'],
#  ['http://instagram.com', '0'],
#  ['http://ask.com', '0'],
#  ['http://paypal.com', '0'],
#  ['http://google.com.hk', '0'],
#  ['http://google.ru', '0'],
#  ['http://blogger.com', '0'],
#  ['http://xvideos.com', '0'],
#  ['http://google.it', '0'],
#  ['http://tmall.com', '0'],
#  ['http://imdb.com', '0'],
#  ['http://google.es', '0'],
#  ['http://craigslist.org', '0'],
#  ['http://sohu.com', '0'],
#  ['http://360.cn', '0'],
#  ['http://go.com', '0'],
#  ['http://bbc.co.uk', '0'],
#  ['http://xhamster.com', '0'],
#  ['http://stackoverflow.com', '0'],
#  ['http://google.com.mx', '0'],
#  ['http://amazon.co.jp', '0'],
#  ['http://cnn.com', '0'],
#  ['http://neobux.com', '0'],
#  ['http://google.ca', '0'],
#  ['http://fc2.com', '0'],
#  ['http://imgur.com', '0'],
#  ['http://youku.com', '0'],
#  ['http://wordpress.org', '0'],
#  ['http://vube.com', '0'],
#  ['http://flickr.com', '0'],
#  ['http://espn.go.com', '0'],
#  ['http://alibaba.com', '0'],
#  ['http://odnoklassniki.ru', '0'],
#  ['http://conduit.com', '0'],
#  ['http://thepiratebay.sx', '0'],
#  ['http://akamaihd.net', '0'],
#  ['http://huffingtonpost.com', '0'],
#  ['http://adcash.com', '0'],
#  ['http://t.co', '0'],
#  ['http://amazon.de', '0'],
#  ['http://google.com.tr', '0'],
#  ['http://godaddy.com', '0'],
#  ['http://pornhub.com', '0'],
#  ['http://blogspot.in', '0'],
#  ['http://about.com', '0'],
#  ['http://ku6.com', '0'],
#  ['http://ebay.de', '0'],
#  ['http://reddit.com', '0'],
#  ['http://bp.blogspot.com', '0'],
#  ['http://google.com.au', '0'],
#  ['http://adobe.com', '0'],
#  ['http://uol.com.br', '0'],
#  ['http://google.pl', '0'],
#  ['http://ebay.co.uk', '0'],
#  ['http://netflix.com', '0'],
#  ['http://dailymotion.com', '0'],
#  ['http://cnet.com', '0'],
#  ['http://delta-search.com', '0'],
#  ['http://dailymail.co.uk', '0'],
#  ['http://rakuten.co.jp', '0'],
#  ['http://aliexpress.com', '0'],
#  ['http://aol.com', '0'],
#  ['http://dce.edu', '0'],
#  ['http://google.com', '0'],
#  ['http://stackoverflow.com/questions/8551735/how-do-i-run-python-code-from-sublime-text-2',
#   '0'],
#  ['http://paypal.com.webscr.cmd.login.submit.dispatch.5885d80a13c0db1f8e263663d3faee8db2b24f7b84f1819343fd6c338b1d9d.222studio.com/UK/',
#   '1'],
#  ['http://paypal-manager-login.net/konflikt/66211165125/', '1'],
#  ['http://paypal-manager-loesung.net/konflikt/66211165125/', '1'],
#  ['http://paypal-manager-account.net/konflikt/66211165125/', '1'],
#  ['http://www.paypal-manager-account.net/konflikt/6222649185/index.php', '1'],
#  ['http://www.paypal-manager-login.net/konflikt/79235228200/index.php', '1'],
#  ['http://paypal.com.laveaki.com.br/PayPal.com/', '1'],
#  ['http://paypal.com.client.identifiant.compte.clefs.informations.upgarde.mon.compte.personnel.ghs56hge556rg4h6qe4th654f84e84r8e.hopitalveterinairedrummond.com/a/payp/Updateto0/index/web/paypal/login/?cmd=_home&dispatch=a430fedacc1fa4f0b709f55224ba5c0ea430fedacc1fa4f0b709f55224ba5c0e',
#   '1'],
#  ['http://msd2003.com/rche/index.htm', '1'],
#  ['http://paypal-manager-loesung.net/konflikt/6624985147/index.php', '1'],
#  ['http://eadideal.com.br/conteudos/material/66/Netzro-Login.html', '1'],
#  ['http://tahmid.ir/user/?cmd=_home&amp;dispatch=5885d80a13c0db1f8e&amp;ee=669498ee5d0b4b381fd2bb1cceb52112',
#   '1'],
#  ['http://208.115.247.198/paypal.com.au.434324.fdsfsd32423423.fadfafas.3423423432fsfdafsdfsd/index1.php',
#   '1'],
#  ['http://www.paypal-manager-service.net/konflikt/785549116/index.php?webapps=/mpp/verkaufen',
#   '1'],
#  ['http://www.nervemobilization.com/update/06bb5b5bd8b1be54b78648f4993a1de1/protect.html',
#   '1'],
#  ['http://www.nervemobilization.com/update/15f58e7e4a736e2cd442b733e8755716/protect.html',
#   '1'],
#  ['http://sionaviatur.ru/wp-includes/syystemyj/index50.htm', '1'],
#  ['http://208.115.247.197/au/index1.php', '1'],
#  ['http://toc.cl/wp-admin/www.sparkasse.de/online-banking.aktualisieren.htm',
#   '1'],
#  ['http://paristokyo.biz/trouvay-cauvin.co.uk/includes/AOL/index.php', '1'],
#  ['http://fenixexpressgc.com/cooljoe/CLICK/CLICK/index.php.htm', '1'],
#  ['http://arbiitours.com/wp-content/plugins/contact-form-777/images/online/login.jsp.html',
#   '1'],
#  ['http://ruthdunn.org/paypal.co.uk.c17d1db50d22aa998bed4a8d7855d5fa03/ffd12b054185e4e1b246b1abc08efb1a/cgi-bin/en/account/login/index.php%5B%2A%2Aqmark%2A%2A%5D',
#   '1'],
#  ['http://civilwarvetswastate.com/gxy/', '1'],
#  ['http://200.98.128.198/testax14/p/itant.html', '1'],
#  ['http://itau.servehttp.com/seguro/processo-adesao.php', '1'],
#  ['http://www.yenimodamodelleri.com/wp_log/Admin/', '1'],
#  ['http://itauguardiao.servehttp.com/blindado/processo-adesao.php', '1'],
#  ['http://www.terrario.org/libraries/jscrop/javascript/ver_2.25/', '1'],
#  ['http://bomberospuertomontt.cl/modules/0299970236/24185239539553/index2.php',
#   '1'],
#  ['http://bitayamashina.ru/8411305558/349325931520424/index2.php', '1'],
#  ['http://ba.dabed1.client.atlantech.net/modules/9065527929/24185239539553/index2.php',
#   '1'],
#  ['http://us.payment.playpal.com.websrc.cmd.8d84f4d5s4f555sd4f8s54f5s48s8s8s5d4f.login.account.554f8sd8sd8.legacyfive.biz/verification/Comp/Comp/',
#   '1'],
#  ['http://us.payment.playpal.com.websrc.cmd.8d84f4d5s4f555sd4f8s54f5s48s8s8s5d4f.login.account.554f8sd8sd8.legacyfive.biz/verification/Comp/Comp/8d0b3059023634d5c323eaffc9db6531/Login/advencev/Done/',
#   '1'],
#  ['http://cookieskeywest.com/modules/8218395246/105328892193242/index2.php',
#   '1'],
#  ['http://us.payment.playpal.com.websrc.cmd.8d84f4d5s4f555sd4f8s54f5s48s8s8s5d4f.login.account.554f8sd8sd8.legacyfive.biz/verification/Comp/Comp/913b469b02247c99ce34cfeea078551a/Login/advencev/Done/',
#   '1'],
#  ['http://bomberospuertomontt.cl/modules/0299970236/105328892193242/index2.php',
#   '1'],
#  ['http://bolanfamily.com/modules/5202682656/105328892193242/index2.php', '1'],
#  ['http://ecocareonline.com/wp-content/themes/Paypal_Virefication/1d7be49f438450a45004dde3aa2fad9f/new1/ad8354d87a30ca581c0d39c8c99eda42/57a1551914f64a14939a926f47f815c5/',
#   '1'],
#  ['http://ans-electric.com/modules/4630490953/24185239539553/index2.php', '1'],
#  ['http://98.130.167.189/modules/6721286628/349325931520424/index2.php', '1'],
#  ['http://fiegerl.com/components/6591932935/24185239539553/index2.php', '1'],
#  ['http://www.eletrorenovadora.com.br/pages/ativacao/webppr/pps8/index2.html?=585d80a13c1f8e263663dd3faee8d35d0e363192f28ea2a5d35d0e363192f28d1bf',
#   '1'],
#  ['http://www.docentesentrerrianos.com/coldwellbanker.com/googledoc/index.htm',
#   '1'],
#  ['http://tierehelfenkindern.de/verification/id=786033625/', '1'],
#  ['http://tierehelfenkindern.de', '1'],
#  ['http://secure.googledrive.com.iphoneturkish.com/new/Googledocs%20Secure.htm',
#   '1'],
#  ['http://secure.googledrive.com.iphoneturkish.com/sec/easyweb.htm', '1'],
#  ['http://tiere-helfen-kindern.de/verification/id=265455776/', '1'],
#  ['http://livedoor.com', '0'],
#  ['http://google.com.tw', '0'],
#  ['http://bannersdontwork.com', '0'],
#  ['http://stumbleupon.com', '0'],
#  ['http://theguardian.com', '0'],
#  ['http://mediafire.com', '0'],
#  ['http://blogfa.com', '0'],
#  ['http://google.co.th', '0'],
#  ['http://torrentz.eu', '0'],
#  ['http://foxnews.com', '0'],
#  ['http://mozilla.org', '0'],
#  ['http://pcpop.com', '0'],
#  ['http://w3schools.com', '0'],
#  ['http://4shared.com', '0'],
#  ['http://forbes.com', '0'],
#  ['http://people.com.cn', '0'],
#  ['http://addthis.com', '0'],
#  ['http://google.co.za', '0'],
#  ['http://media.tumblr.com', '0'],
#  ['http://jrj.com.cn', '0'],
#  ['http://archive.org', '0'],
#  ['http://hostgator.com', '0'],
#  ['http://sourceforge.net', '0'],
#  ['http://lady8844.com', '0'],
#  ['http://badoo.com', '0'],
#  ['http://liveinternet.ru', '0'],
#  ['http://wikihow.com', '0'],
#  ['http://bankofamerica.com', '0'],
#  ['http://files.wordpress.com', '0'],
#  ['http://flipkart.com', '0'],
#  ['http://statcounter.com', '0'],
#  ['http://renren.com', '0'],
#  ['http://spiegel.de', '0'],
#  ['http://google.co.id', '0'],
#  ['http://salesforce.com', '0'],
#  ['http://chase.com', '0'],
#  ['http://warriorforum.com', '0'],
#  ['http://buzzfeed.com', '0'],
#  ['http://jd.com', '0'],
#  ['http://reference.com', '0'],
#  ['http://bet365.com', '0'],
#  ['http://tube8.com', '0'],
#  ['http://mywebsearch.com', '0'],
#  ['http://zedo.com', '0'],
#  ['http://google.com.co', '0'],
#  ['http://soundcloud.com', '0'],
#  ['http://beva.com', '0'],
#  ['http://indeed.com', '0'],
#  ['http://google.gr', '0'],
#  ['http://clkmon.com', '0'],
#  ['http://softonic.com', '0'],
#  ['http://google.com.vn', '0'],
#  ['http://nfl.com', '0'],
#  ['http://mailchimp.com', '0'],
#  ['http://allegro.pl', '0'],
#  ['http://qtrax.com', '0'],
#  ['http://tripadvisor.com', '0'],
#  ['http://photobucket.com', '0'],
#  ['http://google.be', '0'],
#  ['http://mashable.com', '0'],
#  ['http://skype.com', '0'],
#  ['http://walmart.com', '0'],
#  ['http://xyxy.net', '0'],
#  ['http://nbcnews.com', '0'],
#  ['http://gamer.com.tw', '0'],
#  ['http://google.com.ua', '0'],
#  ['http://taringa.net', '0'],
#  ['http://empowernetwork.com', '0'],
#  ['http://bild.de', '0'],
#  ['http://github.com', '0'],
#  ['http://thefreedictionary.com', '0'],
#  ['http://ask.fm', '0'],
#  ['http://google.co.ve', '0'],
#  ['http://onet.pl', '0'],
#  ['http://leboncoin.fr', '0'],
#  ['http://google.com.ng', '0'],
#  ['http://yieldmanager.com', '0'],
#  ['http://nicovideo.jp', '0'],
#  ['http://pconline.com.cn', '0'],
#  ['http://wordreference.com', '0'],
#  ['http://php.net', '0'],
#  ['http://telegraph.co.uk', '0'],
#  ['http://wellsfargo.com', '0'],
#  ['http://uploaded.net', '0'],
#  ['http://wsj.com', '0'],
#  ['http://usatoday.com', '0'],
#  ['http://pandora.com', '0'],
#  ['http://goo.ne.jp', '0'],
#  ['http://shutterstock.com', '0'],
#  ['http://pclady.com.cn', '0'],
#  ['http://comcast.net', '0'],
#  ['http://answers.com', '0'],
#  ['http://google.com.ph', '0'],
#  ['http://amazon.fr', '0'],
#  ['http://google.se', '0'],
#  ['http://rutracker.org', '0'],
#  ['http://google.cn', '0'],
#  ['http://aili.com', '0'],
#  ['http://washingtonpost.com', '0'],
#  ['http://google.ro', '0'],
#  ['http://ikea.com', '0'],
#  ['http://wigetmedia.com', '0'],
#  ['http://zillow.com', '0'],
#  ['http://weebly.com', '0'],
#  ['http://samsung.com', '0'],
#  ['http://wix.com', '0'],
#  ['http://ucoz.ru', '0'],
#  ['http://rambler.ru', '0'],
#  ['http://naver.jp', '0'],
#  ['http://9gag.com', '0'],
#  ['http://qvo6.com', '0'],
#  ['http://mercadolivre.com.br', '0'],
#  ['http://stackexchange.com', '0'],
#  ['http://rediff.com', '0'],
#  ['http://google.dz', '0'],
#  ['http://popads.net', '0'],
#  ['http://google.com.pe', '0'],
#  ['http://ehow.com', '0'],
#  ['http://reuters.com', '0'],
#  ['http://moz.com', '0'],
#  ['http://gmx.net', '0'],
#  ['http://ilivid.com', '0'],
#  ['http://bitauto.com', '0'],
#  ['http://goodreads.com', '0'],
#  ['http://google.com.sg', '0'],
#  ['http://scribd.com', '0'],
#  ['http://ups.com', '0'],
#  ['http://google.at', '0'],
#  ['http://55bbs.com', '0'],
#  ['http://kaskus.co.id', '0'],
#  ['http://bleacherreport.com', '0'],
#  ['http://domaintools.com', '0'],
#  ['http://wp.pl', '0'],
#  ['http://loading-delivery1.com', '0'],
#  ['http://google.ch', '0'],
#  ['http://free.fr', '0'],
#  ['http://marca.com', '0'],
#  ['http://caijing.com.cn', '0'],
#  ['http://constantcontact.com', '0'],
#  ['http://avito.ru', '0'],
#  ['http://businessinsider.com', '0'],
#  ['http://espncricinfo.com', '0'],
#  ['http://goal.com', '0'],
#  ['http://histats.com', '0'],
#  ['http://douban.com', '0'],
#  ['http://youjizz.com', '0'],
#  ['http://hudong.com', '0'],
#  ['http://blogspot.co.uk', '0'],
#  ['http://extratorrent.com', '0'],
#  ['http://56.com', '0'],
#  ['http://onlylady.com', '0'],
#  ['http://google.cl', '0'],
#  ['http://detik.com', '0'],
#  ['http://olx.in', '0'],
#  ['http://hp.com', '0'],
#  ['http://ign.com', '0'],
#  ['http://codecanyon.net', '0'],
#  ['http://clickbank.com', '0'],
#  ['http://hardsextube.com', '0'],
#  ['http://dmm.co.jp', '0'],
#  ['http://bitly.com', '0'],
#  ['http://web.de', '0'],
#  ['http://libero.it', '0'],
#  ['http://infusionsoft.com', '0'],
#  ['http://gsmarena.com', '0'],
#  ['http://cj.com', '0'],
#  ['http://google.pt', '0'],
#  ['http://disqus.com', '0'],
#  ['http://meetup.com', '0'],
#  ['http://google.com.bd', '0'],
#  ['http://enet.com.cn', '0'],
#  ['http://usps.com', '0'],
#  ['http://hurriyet.com.tr', '0'],
#  ['http://in.com', '0'],
#  ['http://varzesh3.com', '0'],
#  ['http://bloomberg.com', '0'],
#  ['http://imageshack.us', '0'],
#  ['http://thefreecamsecret.com', '0'],
#  ['http://fedex.com', '0'],
#  ['http://orange.fr', '0'],
#  ['http://pchome.net', '0'],
#  ['http://mobile01.com', '0'],
#  ['http://voc.com.cn', '0'],
#  ['http://xing.com', '0'],
#  ['http://milliyet.com.tr', '0'],
#  ['http://bluehost.com', '0'],
#  ['http://naver.com', '0'],
#  ['http://hulu.com', '0'],
#  ['http://siteadvisor.com', '0'],
#  ['http://ndtv.com', '0'],
#  ['http://putlocker.com', '0'],
#  ['http://xe.com', '0'],
#  ['http://kooora.com', '0'],
#  ['http://repubblica.it', '0'],
#  ['http://target.com', '0'],
#  ['http://bestbuy.com', '0'],
#  ['http://linkbucks.com', '0'],
#  ['http://google.cz', '0'],
#  ['http://beeg.com', '0'],
#  ['http://istockphoto.com', '0'],
#  ['http://upworthy.com', '0'],
#  ['http://nih.gov', '0'],
#  ['http://chinaz.com', '0'],
#  ['http://motherless.com', '0'],
#  ['http://zol.com.cn', '0'],
#  ['http://ebay.in', '0'],
#  ['http://speedtest.net', '0'],
#  ['http://techcrunch.com', '0'],
#  ['http://webmd.com', '0'],
#  ['http://joomla.org', '0'],
#  ['http://doubleclick.com', '0'],
#  ['http://blogspot.de', '0'],
#  ['http://tianya.cn', '0'],
#  ['http://xinhuanet.com', '0'],
#  ['http://cnzz.com', '0'],
#  ['http://ebay.it', '0'],
#  ['http://ig.com.br', '0'],
#  ['http://elpais.com', '0'],
#  ['http://americanexpress.com', '0'],
#  ['http://pof.com', '0'],
#  ['http://w3.org', '0'],
#  ['http://surveymonkey.com', '0'],
#  ['http://odesk.com', '0'],
#  ['http://zippyshare.com', '0'],
#  ['http://4dsply.com', '0'],
#  ['http://ebay.com.au', '0'],
#  ['http://snapdeal.com', '0'],
#  ['http://quora.com', '0'],
#  ['http://so.com', '0'],
#  ['http://yandex.ua', '0'],
#  ['http://optmd.com', '0'],
#  ['http://quikr.com', '0'],
#  ['http://xcar.com.cn', '0'],
#  ['http://workercn.cn', '0'],
#  ['http://p5w.net', '0'],
#  ['http://jqw.com', '0'],
#  ['http://google.no', '0'],
#  ['http://tudou.com', '0'],
#  ['http://cbssports.com', '0'],
#  ['http://google.com.my', '0'],
#  ['http://tinyurl.com', '0'],
#  ['http://goodgamestudios.com', '0'],
#  ['http://drudgereport.com', '0'],
#  ['http://feedly.com', '0'],
#  ['http://groupon.com', '0'],
#  ['http://google.co.hu', '0'],
#  ['http://webs.com', '0'],
#  ['http://ad6media.fr', '0'],
#  ['http://123rf.com', '0'],
#  ['http://google.ae', '0'],
#  ['http://habrahabr.ru', '0'],
#  ['http://att.com', '0'],
#  ['http://twitch.tv', '0'],
#  ['http://google.ie', '0'],
#  ['http://tagged.com', '0'],
#  ['http://blackhatworld.com', '0'],
#  ['http://hdfcbank.com', '0'],
#  ['http://getresponse.com', '0'],
#  ['http://dell.com', '0'],
#  ['http://mlb.com', '0'],
#  ['http://trafficunit.in', '0'],
#  ['http://match.com', '0'],
#  ['http://freelancer.com', '0'],
#  ['http://kakaku.com', '0'],
#  ['http://gazeta.pl', '0'],
#  ['http://elmundo.es', '0'],
#  ['http://goo.gl', '0'],
#  ['http://t-online.de', '0'],
#  ['http://clixsense.com', '0'],
#  ['http://twoo.com', '0'],
#  ['http://terra.com.br', '0'],
#  ['http://abcnews.go.com', '0'],
#  ['http://google.co.kr', '0'],
#  ['http://zendesk.com', '0'],
#  ['http://seznam.cz', '0'],
#  ['http://rapidgator.net', '0'],
#  ['http://uimserv.net', '0'],
#  ['http://rt.com', '0'],
#  ['http://eyny.com', '0'],
#  ['http://abril.com.br', '0'],
#  ['http://ameba.jp', '0'],
#  ['http://microsoftonline.com', '0'],
#  ['http://naukri.com', '0'],
#  ['http://blogspot.fr', '0'],
#  ['http://clicksor.com', '0'],
#  ['http://39.net', '0'],
#  ['http://time.com', '0'],
#  ['http://google.dk', '0'],
#  ['http://force.com', '0'],
#  ['http://webcrawler.com', '0'],
#  ['http://intoday.in', '0'],
#  ['http://ning.com', '0'],
#  ['http://ck101.com', '0'],
#  ['http://corriere.it', '0'],
#  ['http://google.az', '0'],
#  ['http://latimes.com', '0'],
#  ['http://pcbaby.com.cn', '0'],
#  ['http://jimdo.com', '0'],
#  ['http://cloudfront.net', '0'],
#  ['http://elance.com', '0'],
#  ['http://likes.com', '0'],
#  ['http://typepad.com', '0'],
#  ['http://webmoney.ru', '0'],
#  ['http://list-manage.com', '0'],
#  ['http://capitalone.com', '0'],
#  ['http://pch.com', '0'],
#  ['http://adultfriendfinder.com', '0'],
#  ['http://youm7.com', '0'],
#  ['http://commentcamarche.net', '0'],
#  ['http://fbcdn.net', '0'],
#  ['http://google.co.il', '0'],
#  ['http://58.com', '0'],
#  ['http://retailmenot.com', '0'],
#  ['http://hypergames.net', '0'],
#  ['http://liveleak.com', '0'],
#  ['http://lemonde.fr', '0'],
#  ['http://exoclick.com', '0'],
#  ['http://java.com', '0'],
#  ['http://livescore.com', '0'],
#  ['http://foursquare.com', '0'],
#  ['http://xgo.com.cn', '0'],
#  ['http://sahibinden.com', '0'],
#  ['http://isohunt.com', '0'],
#  ['http://okcupid.com', '0'],
#  ['http://m2newmedia.com', '0'],
#  ['http://chaturbate.com', '0'],
#  ['http://doorblog.jp', '0'],
#  ['http://ettoday.net', '0'],
#  ['http://xda-developers.com', '0'],
#  ['http://lenovo.com', '0'],
#  ['http://fotolia.com', '0'],
#  ['http://engadget.com', '0'],
#  ['http://semrush.com', '0'],
#  ['http://doublepimp.com', '0'],
#  ['http://shaadi.com', '0'],
#  ['http://nydailynews.com', '0'],
#  ['http://myfreecams.com', '0'],
#  ['http://digg.com', '0'],
#  ['http://drtuber.com', '0'],
#  ['http://verizonwireless.com', '0'],
#  ['http://mercadolibre.com.ar', '0'],
#  ['http://issuu.com', '0'],
#  ['http://swagbucks.com', '0'],
#  ['http://searchengines.ru', '0'],
#  ['http://sape.ru', '0'],
#  ['http://snapdo.com', '0'],
#  ['http://expedia.com', '0'],
#  ['http://vnexpress.net', '0'],
#  ['http://narod.ru', '0'],
#  ['http://taleo.net', '0'],
#  ['http://bodybuilding.com', '0'],
#  ['http://icicibank.com', '0'],
#  ['http://backpage.com', '0'],
#  ['http://iqiyi.com', '0'],
#  ['http://gutefrage.net', '0'],
#  ['http://amazon.it', '0'],
#  ['http://baomihua.com', '0'],
#  ['http://hubspot.com', '0'],
#  ['http://tmz.com', '0'],
#  ['http://ebay.fr', '0'],
#  ['http://tlbb8.com', '0'],
#  ['http://eventbrite.com', '0'],
#  ['http://shareasale.com', '0'],
#  ['http://zing.vn', '0'],
#  ['http://news.com.au', '0'],
#  ['http://who.is', '0'],
#  ['http://xunlei.com', '0'],
#  ['http://kijiji.ca', '0'],
#  ['http://gotomeeting.com', '0'],
#  ['http://lifehacker.com', '0'],
#  ['http://oracle.com', '0'],
#  ['http://lenta.ru', '0'],
#  ['http://kickstarter.com', '0'],
#  ['http://subscene.com', '0'],
#  ['http://homedepot.com', '0'],
#  ['http://hatena.ne.jp', '0'],
#  ['http://namecheap.com', '0'],
#  ['http://gawker.com', '0'],
#  ['http://blogspot.ru', '0'],
#  ['http://bhaskar.com', '0'],
#  ['http://accuweather.com', '0'],
#  ['http://justdial.com', '0'],
#  ['http://en.wordpress.com', '0'],
#  ['http://github.io', '0'],
#  ['http://altervista.org', '0'],
#  ['http://soku.com', '0'],
#  ['http://majesticseo.com', '0'],
#  ['http://chip.de', '0'],
#  ['http://rbc.ru', '0'],
#  ['http://probux.com', '0'],
#  ['http://theblaze.com', '0'],
#  ['http://sberbank.ru', '0'],
#  ['http://lefigaro.fr', '0'],
#  ['http://6.cn', '0'],
#  ['http://google.sk', '0'],
#  ['http://gizmodo.com', '0'],
#  ['http://mihanblog.com', '0'],
#  ['http://timeanddate.com', '0'],
#  ['http://amazon.cn', '0'],
#  ['http://newegg.com', '0'],
#  ['http://trulia.com', '0'],
#  ['http://monster.com', '0'],
#  ['http://opensiteexplorer.org', '0'],
#  ['http://amung.us', '0'],
#  ['http://kompas.com', '0'],
#  ['http://yxlady.com', '0'],
#  ['http://2ch.net', '0'],
#  ['http://ya.ru', '0'],
#  ['http://hubpages.com', '0'],
#  ['http://kinopoisk.ru', '0'],
#  ['http://citrixonline.com', '0'],
#  ['http://foxsports.com', '0'],
#  ['http://onlinesbi.com', '0'],
#  ['http://wired.com', '0'],
#  ['http://battle.net', '0'],
#  ['http://wiktionary.org', '0'],
#  ['http://eastday.com', '0'],
#  ['http://oneindia.in', '0'],
#  ['http://steampowered.com', '0'],
#  ['http://templatemonster.com', '0'],
#  ['http://marketwatch.com', '0'],
#  ['http://mercadolibre.com.mx', '0'],
#  ['http://jquery.com', '0'],
#  ['http://moneycontrol.com', '0'],
#  ['http://jabong.com', '0'],
#  ['http://farsnews.com', '0'],
#  ['http://traidnt.net', '0'],
#  ['http://wissensbilanz.ch', '1'],
#  ['http://larafabiannews.kit.net', '1'],
#  ['http://manavgatim.net', '1'],
#  ['http://megasuits.wordpress.com', '1'],
#  ['http://mens-fashions.blogspot.com', '1'],
#  ['http://elegant-mens-apparel.blogspot.com', '1'],
#  ['http://fondane.eu', '1'],
#  ['http://blogven.net', '1'],
#  ['http://sexoroid.com', '1'],
#  ['http://hotelslloret.com', '1'],
#  ['http://corluhaber.com', '1'],
#  ['http://labottegadimartone.it', '1'],
#  ['http://stilnakliyat.com', '1'],
#  ['http://idiomfox.com', '1'],
#  ['http://shadyrunstudios.tripod.com', '1'],
#  ['http://in-grid.com.pl', '1'],
#  ['http://morandi.one.pl', '1'],
#  ['http://cascada.xt.pl', '1'],
#  ['http://ingrid.wot.pl', '1'],
#  ['http://in-grid.xt.pl', '1'],
#  ['http://mardelbuscador.com', '1'],
#  ['http://super-masini-tuning.blogspot.com', '1'],
#  ['http://ramabeach.com', '1'],
#  ['http://zambales.ph', '1'],
#  ['http://antoniocarlosmachado.com', '1'],
#  ['http://ciaux.com', '1'],
#  ['http://guia.com', '1'],
#  ['http://guidesaopaulo.com', '1'],
#  ['http://iberovision.com', '1'],
#  ['http://leamachado.com', '1'],
#  ['http://negocioreal.net', '1'],
#  ['http://netsaopaulo.com', '1'],
#  ['http://portalsaopaulo.com', '1'],
#  ['http://premiumflats.com', '1'],
#  ['http://saopaulo.com', '1'],
#  ['http://taubate.com', '1'],
#  ['http://nutshellurl.com', '1'],
#  ['http://cjb.net', '1'],
#  ['http://uni.cc', '1'],
#  ['http://vai.la', '1'],
#  ['http://k6.com.br', '1'],
#  ['http://s9k.net', '1'],
#  ['http://v3.com', '1'],
#  ['http://cab8.net', '1'],
#  ['http://rg3.net', '1'],
#  ['http://rg9.net', '1'],
#  ['http://rg10.net', '1'],
#  ['http://br30.com', '1'],
#  ['http://midominiogratis.com', '1'],
#  ['http://1br.net', '1'],
#  ['http://sitio.de', '1'],
#  ['http://clic3.net', '1'],
#  ['http://url.ie', '1'],
#  ['http://dunesdugolf.eu', '1'],
#  ['http://avsam.com.tr', '1'],
#  ['http://avsaadasi.gen.tr', '1'],
#  ['http://zoodl.com', '1'],
#  ['http://abc1.eu', '1'],
#  ['http://article19.eu', '1'],
#  ['http://beira.us', '1'],
#  ['http://besides.tv', '1'],
#  ['http://blasphemy.asia.com', '1'],
#  ['http://borderline.asia.com', '1'],
#  ['http://buckhead.asia', '1'],
#  ['http://careerbuilding.net', '1'],
#  ['http://centralasia.asia.com', '1'],
#  ['http://cepf.eu', '1'],
#  ['http://chinese.uz', '1'],
#  ['http://clickpage.net', '1'],
#  ['http://cnlhotels.com', '1'],
#  ['http://discover-places.com', '1'],
#  ['http://e-shopping.asia.com', '1'],
#  ['http://emcef.eu', '1'],
#  ['http://emissions.asia.com', '1'],
#  ['http://euromalt.eu', '1'],
#  ['http://exclusive.asia.com', '1'],
#  ['http://express247.com', '1'],
#  ['http://fertile.mobi', '1'],
#  ['http://finished.tv', '1'],
#  ['http://gateway.us', '1'],
#  ['http://ggeat.com', '1'],
#  ['http://glitch.asia.com', '1'],
#  ['http://holidaybug.com', '1'],
#  ['http://homesaid.com', '1'],
#  ['http://hostile.asia.com', '1'],
#  ['http://instore.net', '1'],
#  ['http://karshi.asia.com', '1'],
#  ['http://moonlight.asia.com', '1'],
#  ['http://namecout.com', '1'],
#  ['http://nbsp.us', '1'],
#  ['http://neither.tv', '1'],
#  ['http://newyorkrealestate.eu', '1'],
#  ['http://onlinecasinoreview.biz', '1'],
#  ['http://parishilton.asia', '1'],
#  ['http://photosuites.com', '1'],
#  ['http://pyzza.net', '1'],
#  ['http://ratar.com', '1'],
#  ['http://sand.mobi', '1'],
#  ['http://satte.asia.com', '1'],
#  ['http://seikh.com', '1'],
#  ['http://spread.mobi', '1'],
#  ['http://stan.asia.com', '1'],
#  ['http://striper.asia.com', '1'],
#  ['http://surprised.tv', '1'],
#  ['http://swf.asia.com', '1'],
#  ['http://terminus.asia.com', '1'],
#  ['http://thinks.tv', '1'],
#  ['http://turkmenistan.asia', '1'],
#  ['http://solomonislands.com', '1'],
#  ['http://world.info', '1'],
#  ['http://vvjz.com', '1'],
#  ['http://wikiaction.com', '1'],
#  ['http://wondering.tv', '1'],
#  ['http://yalta.asia.com', '1'],
#  ['http://industrialstrengthstaging.com', '1'],
#  ['http://gbcattani.com', '1'],
#  ['http://espadrilles.com', '1'],
#  ['http://easyurl.net', '1'],
#  ['http://filminformation.blogspot.com', '1'],
#  ['http://w3t.org', '1'],
#  ['http://alturl.com', '1'],
#  ['http://shorturl.com', '1'],
#  ['http://russianworld.com.au', '1'],
#  ['http://weatherpage.com.au', '1'],
#  ['http://tripleme.com', '1'],
#  ['http://russianworld.co.nz', '1'],
#  ['http://russiannewzealand.com', '1'],
#  ['http://triplemecom.blogspot.com', '1'],
#  ['http://peopleschocolate.com', '1'],
#  ['http://cwill1.com', '1'],
#  ['http://josoleil.com', '1'],
#  ['http://faucongris.com', '1'],
#  ['http://grey-falcon.com', '1'],
#  ['http://axebet.com', '1'],
#  ['http://sanyaweb.com', '1'],
#  ['http://mundo-ocio.es', '1'],
#  ['http://putin.ru', '1'],
#  ['http://xurl.jp', '1'],
#  ['http://cloakedlink.com', '1'],
#  ['http://millesabords.net', '1'],
#  ['http://tharmada.net', '1'],
#  ['http://mihaisora.eu', '1'],
#  ['http://quran.waraqat.net', '1'],
#  ['http://rs2pl.com', '1'],
#  ['http://nelioguerson.palcomp3.com.br', '1'],
#  ['http://myspace.com/fantomenk', '1'],
#  ['http://vente-privee.com/vp4/Registration/Registration.aspx?', '1'],
#  ['http://mistureca.blogspot.com', '1'],
#  ['http://givemeknol.com', '1'],
#  ['http://maxreading.com', '1'],
#  ['http://trucchi-e-consigli-msn.spaces.live.com', '1'],
#  ['http://speechcorrector.org', '1'],
#  ['http://mcdo3333.blogspot.com', '1'],
#  ['http://litlurl.net', '1'],
#  ['http://bozkir.com', '1'],
#  ['http://1classical.com', '1'],
#  ['http://comoj.com', '1'],
#  ['http://psychology.tk', '1'],
#  ['http://payel.tk', '1'],
#  ['http://azpayel.blogspot.com', '1'],
#  ['http://plagecorse.com', '1'],
#  ['http://gamewatch.com.es', '1'],
#  ['http://migre.me', '1'],
#  ['http://cabinas.net', '1'],
#  ['http://seekinusa.com', '1'],
#  ['http://elargentino.net', '1'],
#  ['http://komik-fikralar.net', '1'],
#  ['http://the-locos.com', '1'],
#  ['http://satelliteview.org', '1'],
#  ['http://secure-x-001.net', '1'],
#  ['http://pornoxo.com', '1'],
#  ['http://ladonia.net', '1'],
#  ['http://cyborg009.it', '1'],
#  ['http://abbr.com', '1'],
#  ['http://abe5.com', '1'],
#  ['http://gospelhearts.synthasite.com', '1'],
#  ['http://busty.pl', '1'],
#  ['http://moourl.com', '1'],
#  ['http://pepekanavis.org', '1'],
#  ['http://serkann.com', '1'],
#  ['http://strongvpn.com', '1'],
#  ['http://gentefresa.com', '1'],
#  ['http://own3d.es', '1'],
#  ['http://masfresa.com', '1'],
#  ['http://recaero.fr', '1'],
#  ['http://yfrog.com', '1'],
#  ['http://aforismi.awardspace.com', '1'],
#  ['http://tebesirim.com', '1'],
#  ['http://vinyland.com', '1'],
#  ['http://ciquestudios.com', '1'],
#  ['http://pageditorpro.com', '1'],
#  ['http://siremfc.marlito.com', '1'],
#  ['http://kaspersky-key.net', '1'],
#  ['http://spikey.com', '1'],
#  ['http://learningrussian.net', '1'],
#  ['http://europeopen.org.uk', '1'],
#  ['http://graffiti.cs.brown.edu', '1'],
#  ['http://aekition.blogspot.com', '1'],
#  ['http://mmafight.ru', '1'],
#  ['http://realestatesky.net', '1'],
#  ['http://orchidea.com.ua', '1'],
#  ['http://catalanschool.com', '1'],
#  ['http://webweevers.com', '1'],
#  ['http://urlmin.com', '1'],
#  ['http://invx.com', '1'],
#  ['http://moya-shkola.info', '1'],
#  ['http://jimmywales.org', '1'],
#  ['http://jimmywales.com', '1'],
#  ['http://bindiirwin.com', '1'],
#  ['http://nataliebassingthwaighte.net', '1'],
#  ['http://vickydarling.com', '1'],
#  ['http://hugeurl.com', '1'],
#  ['http://freakinghugeurl.com', '1'],
#  ['http://tangodans.com', '1'],
#  ['http://(?<!www.)mybrute.com', '1'],
#  ['http://mybrutehacks.forumotion.com', '1'],
#  ['http://pfx.me', '1'],
#  ['http://casareal.co.pt', '1'],
#  ['http://partypillsonline', '1'],
#  ['http://liveresumeexamples.com', '1'],
#  ['http://best-cv-templates.com', '1'],
#  ['http://perfectgirls.net', '1'],
#  ['http://4tube.com', '1'],
#  ['http://visalusshakes.com', '1'],
#  ['http://101juegosdeautos.com', '1'],
#  ['http://monclerjacketsd', '1'],
#  ['http://sistemas.fciencias.unam.mx', '1'],
#  ['http://cpesamplewritings.blogspot.com', '1'],
#  ['http://e621.net', '1'],
#  ['http://ezadblaster.com', '1'],
#  ['http://freeonlinedating', '1'],
#  ['http://medrxshop', '1'],
#  ['http://buy.?adipex.?online', '1'],
#  ['http://videodeteen.eu', '1'],
#  ['http://shark.net.pl', '1'],
#  ['http://powerfulhacks.com', '1'],
#  ['http://sloganexpert.com', '1'],
#  ['http://2u.lc', '1'],
#  ['http://owl.li', '1'],
#  ['http://shorten.me', '1'],
#  ['http://yourshortlink.net', '1'],
#  ['http://penilegain', '1'],
#  ['http://cheatyworld.com', '1'],
#  ['http://uu.gl', '1'],
#  ['http://neoplano.com', '1'],
#  ['http://tancredi.com', '1'],
#  ['http://getxanax.com', '1'],
#  ['http://www-mp3player.com', '1'],
#  ['http://nikesfactory.com', '1'],
#  ['http://actionseoservices.com', '1'],
#  ['http://getwebvisitors.com', '1'],
#  ['http://getloanslendersusa.org', '1'],
#  ['http://doghematerassi.it', '1'],
#  ['http://icigarettes.com', '1'],
#  ['http://buycheappillsonline.com', '1'],
#  ['http://rapidfatloss.com', '1'],
#  ['http://ladamejeanne.fr', '1'],
#  ['http://bestseoservices', '1'],
#  ['http://avantpack.ru', '1'],
#  ['http://plus.lapvo3.tk', '1'],
#  ['http://politician.to', '1'],
#  ['http://youtube.com/watch?v=oVBOnv-xrEY', '1'],
#  ['http://shopforpainrelief.com', '1'],
#  ['http://printforprofits.com', '1'],
#  ['http://sexndfunny.biz', '1'],
#  ['http://ladamejeanne.fr', '1'],
#  ['http://lcdscreenforlaptops.com', '1'],
#  ['http://website-Ranking-Checker.com', '1'],
#  ['http://magiclondonescorts.com', '1'],
#  ['http://brunetteescorts4u.com', '1'],
#  ['http://achimthepooh.de', '1'],
#  ['http://memopadhd7.gweb.io', '1'],
#  ['http://hxiv.me', '1'],
#  ['http://mgjmp.com', '1'],
#  ['http://orelsetka.ru', '1'],
#  ['http://prespa-birlik.se', '1'],
#  ['http://recoverymechanic.com', '1'],
#  ['http://segue.se', '1'],
#  ['http://dietplanstolose.com', '1'],
#  ['http://weightwatcherscoupons', '1'],
#  ['http://mortgagewoodbridgevirginia.com', '1']]

# %%
url = pd.DataFrame(url, columns=('URL', 'Label'))

# %%
url.head()
# Out:
#                    URL Label
# 0    http://google.com     0
# 1  http://facebook.com     0
# 2   http://youtube.com     0
# 3     http://yahoo.com     0
# 4     http://baidu.com     0

# %%
data = pd.concat([clean_url, malicious_url, url])

# %%
data.drop_duplicates()
# Out:
#                                         URL Label
# 0                        https://google.com     0
# 1                       https://youtube.com     0
# 2                      https://facebook.com     0
# 3                         https://baidu.com     0
# 4                     https://wikipedia.org     0
# 5                        https://reddit.com     0
# 6                         https://yahoo.com     0
# 7                      https://google.co.in     0
# 8                            https://qq.com     0
# 9                        https://amazon.com     0
# 10                       https://taobao.com     0
# 11                      https://twitter.com     0
# 12                        https://tmall.com     0
# 13                     https://google.co.jp     0
# 14                           https://vk.com     0
# 15                         https://live.com     0
# 16                    https://instagram.com     0
# 17                         https://sohu.com     0
# 18                      https://sina.com.cn     0
# 19                           https://jd.com     0
# 20                        https://weibo.com     0
# 21                           https://360.cn     0
# 22                        https://google.de     0
# 23                     https://google.co.uk     0
# 24                    https://google.com.br     0
# 25                        https://google.fr     0
# 26                        https://google.ru     0
# 27                      https://netflix.com     0
# 28                        https://yandex.ru     0
# 29                   https://list.tmall.com     0
# ..                                      ...   ...
# 827               http://getwebvisitors.com     1
# 828           http://getloanslendersusa.org     1
# 829                http://doghematerassi.it     1
# 830                  http://icigarettes.com     1
# 831          http://buycheappillsonline.com     1
# 832                 http://rapidfatloss.com     1
# 833                  http://ladamejeanne.fr     1
# 834                  http://bestseoservices     1
# 835                     http://avantpack.ru     1
# 836                   http://plus.lapvo3.tk     1
# 837                    http://politician.to     1
# 838  http://youtube.com/watch?v=oVBOnv-xrEY     1
# 839            http://shopforpainrelief.com     1
# 840              http://printforprofits.com     1
# 841                   http://sexndfunny.biz     1
# 843          http://lcdscreenforlaptops.com     1
# 844      http://website-Ranking-Checker.com     1
# 845           http://magiclondonescorts.com     1
# 846            http://brunetteescorts4u.com     1
# 847                  http://achimthepooh.de     1
# 848               http://memopadhd7.gweb.io     1
# 849                          http://hxiv.me     1
# 850                        http://mgjmp.com     1
# 851                     http://orelsetka.ru     1
# 852                 http://prespa-birlik.se     1
# 853             http://recoverymechanic.com     1
# 854                         http://segue.se     1
# 855              http://dietplanstolose.com     1
# 856            http://weightwatcherscoupons     1
# 857   http://mortgagewoodbridgevirginia.com     1
#
# [5894 rows x 2 columns]

# %%
data.drop_duplicates().to_csv('../DataSet/data.csv', index=False)

# %%
data = pd.read_csv('../DataSet/data.csv')

# %%
data.head()
# Out:
#                      URL  Label
# 0     https://google.com      0
# 1    https://youtube.com      0
# 2   https://facebook.com      0
# 3      https://baidu.com      0
# 4  https://wikipedia.org      0

# %%
data.shape
# Out:
# (5894, 2)

# %%
from sklearn.utils import shuffle

# %%
data = shuffle(data)

# %%
data.reset_index(drop=True)
# Out:
#                                                     URL  Label
# 0                                     https://houzz.com      0
# 1     https://ve-protect002.000webhostapp.com/paymen...      1
# 2                                   http://vinyland.com      1
# 3                                      http://fedex.com      0
# 4                                http://getresponse.com      0
# 5                      http://vilargroup.by/index/chase      1
# 6     http://www.assurednet.com.au/fixn/chase/login/...      1
# 7                                       https://nhl.com      0
# 8                                      http://seikh.com      1
# 9                                https://sf-express.com      0
# 10    http://team-recovery-program.biz/help/recovery...      1
# 11                                       https://qq.com      0
# 12                                    https://pcmag.com      0
# 13                                  https://livedoor.jp      0
# 14                                  http://terra.com.br      0
# 15    http://saylaestate.com/wp-admin/user/webmr-ed....      1
# 16    http://info02887166ft.000webhostapp.com/Paymen...      1
# 17    http://account-chek-police.000webhostapp.com/p...      1
# 18                                  https://samsung.com      0
# 19    https://pandaybaaz.com/Onedrivepdf/OneDrive/in...      1
# 20    https://sites.google.com/site/policynotif0192/...      1
# 21                            https://sarkariresult.com      0
# 22                                    https://4chan.org      0
# 23                                 https://20minutos.es      0
# 24    http://tc-admin.be/chase/1c292c4713ff31b738c9c...      1
# 25                               http://telegraph.co.uk      0
# 26     https://sites.google.com/site/policyclaming7648/      1
# 27                            https://wordreference.com      0
# 28                                 https://camdolls.com      0
# 29    http://foreverdivine.com.au/info/recovery-answ...      1
# ...                                                 ...    ...
# 5864                                https://wikiwiki.jp      0
# 5865  http://secure-2018.000webhostapp.com/Payment-u...      1
# 5866                                   https://weibo.cn      0
# 5867                                 https://alipay.com      0
# 5868                                      https://vg.no      0
# 5869                        https://brazzersnetwork.com      0
# 5870  http://www.team-recovery-program.biz/help/Paym...      1
# 5871                                    https://ansa.it      0
# 5872                             https://streamable.com      0
# 5873                               https://mashable.com      0
# 5874  http://altorgdv.ru/web/index1.php?l=_JeHFUq_VJ...      1
# 5875  https://www.naturaljuices.co.uk/bbooc/home_2/l...      1
# 5876  http://thecashcowformula.net/account/webby/ver...      1
# 5877  http://portal-account-security-officers-in-201...      1
# 5878                                   https://cam4.com      0
# 5879                                    https://redd.it      0
# 5880   http://www.whymcgrath.com.au/wp-includes/js/hot/      1
# 5881  http://club-liner.de/auth/5f5866399927277de556...      1
# 5882                                   https://gdax.com      0
# 5883  http://smokesonstate.com/Gssss/Gssss/2c5599c25...      1
# 5884  http://ameli-remboursement.cf/login/Assurance/...      1
# 5885                                   https://biqle.ru      0
# 5886                              https://manhuagui.com      0
# 5887                                  https://xuite.net      0
# 5888  http://www.bunnyamin.com/ho/hotis/step2-authen...      1
# 5889                                http://nicovideo.jp      0
# 5890  http://page.app5slite.com/?page=what-s-app&amp...      1
# 5891                                  https://delta.com      0
# 5892                 http://secomea.cn/mail/strdropbox/      1
# 5893         https://sites.google.com/site/vip01secure/      1
#
# [5894 rows x 2 columns]

# %%
data1 = pd.read_csv('../DataSet/New Folder/dataset.csv')

# %%
data = shuffle(pd.concat([shuffle(data1[data1['Label'] == 1])[:1053], shuffle(data1[data1['Label'] == 0])[:1053], data]).reset_index(drop=True)).reset_index(drop=True)
